# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import TweetTokenizer, RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

from code.cleaner import preprocess
from code.viz import word_plot

sns.set()

# %%
sentiments = pd.read_csv('./data/judge-1377884607_tweet_product_company.csv',encoding='ISO-8859-1')
sentiments.tail()
# Out:
#                                              tweet_text  \
# 9088                      Ipad everywhere. #SXSW {link}
# 9089  Wave, buzz... RT @mention We interrupt your re...
# 9090  Google's Zeiger, a physician never reported po...
# 9091  Some Verizon iPhone customers complained their...
# 9092  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
#
#      emotion_in_tweet_is_directed_at  \
# 9088                            iPad
# 9089                             NaN
# 9090                             NaN
# 9091                             NaN
# 9092                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 9088                                   Positive emotion
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product

# %%
# sentiments['product'] = sentiments['emotion_in_tweet_is_directed_at']
# sentiments['sentiment'] = sentiments['is_there_an_emotion_directed_at_a_brand_or_product']

sentiments.rename(columns={
    'emotion_in_tweet_is_directed_at':'product',
    'is_there_an_emotion_directed_at_a_brand_or_product':'sentiment'
},inplace=True)

# %%
sentiments.dropna(subset=['tweet_text'],inplace=True)

# %%
sentiments['sentiment'].value_counts()
# Out:
# No emotion toward brand or product    5388
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: sentiment, dtype: int64

# %% [markdown]
# Here, we'll split off the sentiments listed as "I can't
# tell" into their own dataframe and drop them from the
# original.

# %%
reclassify = sentiments[sentiments['sentiment'] == "I can't tell"]
sentiments = sentiments[sentiments['sentiment'] != "I can't tell"]

# %%
sw = stopwords.words('english')
specific_words = ['@mention','link','sxsw','#sxsw','@sxsw']
# ^^ these are the original extended stop words from initial data
# discovery and knowledge 
discovered_words = [
    'google','iphone', 'ipad', 'android', 'app',
    'apple', 'rt', 'quot', 'store', 'new', 'austin'
    ]
specific_words.extend(discovered_words)
sw.extend(specific_words)

# %%
preprocess(sentiments['tweet_text'],sw)
# Out:
# ['@wesley g hr tweet #rise dead need upgrade plugin station',
#  '@jessedee know @fludapp awesome likely appreciate design also give free t',
#  '@swonderlin wait #ipad also sale',
#  'hope year festival crashy year',
#  '@sxtxstate great stuff fri marissa mayer tim reilly tech book conference amp matt mullenweg wordpress',
#  '@teachntech apps #speechtherapy communication showcased conference http ht ly n #iear #edchat #asd',
#  'start #ctia around corner #googleio hop skip jump good time #android fan',
#  'beautifully smart simple idea @madebymany @thenextweb write #hollergram http bit ly ieavob',
#  'counting day plus strong canadian dollar mean stock gear',
#  'excited meet @samsungmobileus show sprint galaxy still run #fail',
#  'find amp start impromptu party @hurricaneparty http bit ly gvlrin wait til come',
#  'foursquare ups game time http j mp grn pk still prefer @gowalla far best look date',
#  'gotta love calendar feature top party show case check @hamsandwich via @ischafer gt http bit ly axzwxb',
#  'great @madebymany http tinyurl com nqv l',
#  'haha awesomely rad @madebymany http bit ly htdfim #hollergram',
#  'holler gram itunes http co kfn f q via @marc ken',
#  'noticed dst come weekend many user hour late come sunday morning #iphone',
#  'added flight @planely match people plane airport also download @klm nicely do',
#  'must @malbonster lovely review forbes holler gram http co g gzypv',
#  'need buy sure need q',
#  'oh god pure unadulterated awesome easy browse event website',
#  'okay really yay @foursquare #android kthxbai',
#  'photo instal really nice http tumblr com x pi av',
#  'really enjoy change gowalla look forward see else amp foursquare sleeve',
#  '@laurieshook look forward #smcdallas pre party wed hop win #ipad result shameless promotion #chevysmc',
#  'haha awesomely rad @madebymany http bit ly htdfim #hollergram via @michaelpiliero',
#  'someone start #austin @partnerhub group group pre great idea',
#  'sq look like go rock update push tonight http bit ly etsbzk #keepaustinweird',
#  'right @gowalla #android sweeeeet nice job team',
#  'smart @madebymany #hollergram http co xvwc may leave vuvuzela home',
#  'must go http itunes com u holler gram id mt #hollergram',
#  'attn frineds register #gdgtlive see cobra iradar',
#  'anyone want sell old',
#  'anyone buy want sell old',
#  'oooh launch major social network call circle possibly today',
#  'best ha first line #ipad pop event planner #eventprofs #pcma #engage',
#  'spin play concept music discovery amp spin com #itunes',
#  'false alarm circle come probably ever #google #circles #social',
#  'vatornews force print medium evolve',
#  'great weather greet still need sweater night put flash downtown sell',
#  'hootsuite hootsuite mobile update blackberry amp whether get friend',
#  'hey long think take u make case answer use #zazzlesxsw make one',
#  'mashable take video #ipad #gadgets',
#  'pad #ubersocial #iphone include uberguide sponsor',
#  '#ipad #smartcover open instant access wait get one #apple',
#  'hand hold hobo drafthouse launch hobo shotgun',
#  'hooray open pop',
#  'orly set launch social network #circles today',
#  'wooooo downtown open til midnight',
#  'khoi vinh say conde nast headlong rush publishing fundamental misunderstanding platform',
#  'lt help forward doc anonymous account techie amp ppl help u jam #libya',
#  '#edchat #musedchat #sxswi #classical #newtwitter',
#  'location base fast fun future via',
#  '#google connect digital amp physical world mobile',
#  'talk effort allow user open system #bettercloud',
#  'tweet think speak mark belinsky tweet panel',
#  'st stop #chaos amp hunt java get spy game chance win',
#  'check holler gram',
#  'amp fun #google pic',
#  'via guy kawasaki talk enchant know stuff #books #internet #apple',
#  '#futuremf spec recipe web search',
#  '#omfg hear pop downtown pic already gowalla #ipad',
#  '#smile think pop would lot interest actually know popped',
#  'line insane',
#  'agree wait fiona town somebody kidnap put record studio record album',
#  'wanna buy drink pm fado th join u',
#  'attend design headache',
#  'boooo flipboard develop version say',
#  'check amp line power #sxswi',
#  'check give add value location base service needs battle check fatigue #google #pnid',
#  'chilcott stand talk blogger staff late win competition best tweet mention shirt',
#  'come party w tonight band food art ice cream nifty interactive map',
#  'gowalla promise launch foursquare check groupon reward type service finger cross',
#  'ha ha news yahoo com loose search traffic site com doubt last tho w weird name',
#  'holla party best ever get butt',
#  'love case get phone #fail',
#  'worship',
#  'droid amp mac #agnerd confession use laptop amp blackberry follow',
#  'launch denies social network call circle debut today despite report',
#  'post make easy connect social network people meet',
#  'nice behave today crash yesterday ridiculous',
#  'nice open popup launch downtown via',
#  'nice hey fan get peek space slat pop tomorrow',
#  'one thing great get great earth face company love #sxwsi',
#  'stay tune showcase #h ckers',
#  'thank #touchingstories preso deck',
#  'thank awesome party',
#  'thanks try contact friend family #japan create person finder',
#  'thanks mention #speech apps showcased conf #sxswh #sxsh',
#  'thanks publish news medical apps #sxswi conf blog #sxswh #mhealth',
#  'provide charger change mind go next year',
#  'wonder amp flashmob tcrn ch fcs j #ipad',
#  'wonder put tip api #suxsw',
#  'xmas shiny apps @garyvee book pop store christmas nerd',
#  'yai #ubersocial #iphone include uberguide sponsor cont',
#  'yes hey get another gem gt free',
#  'fast fun amp future present search local mobile',
#  'gsd amp amp industry party tonight see u #austin #welivehere #gsdm',
#  'buzz launch major social network call circle possibly today',
#  'headline #ipad must gadget hmm could see one come #gadget',
#  'know dataviz translates satanic sayin',
#  'launch checkins month ago check in ok check out future #bizzy',
#  'launch checkins month ago check in ok check out future #bizzy via',
#  'tweet think speak mark belinsky tweet panel',
#  'attend leave brain search right brain search x #bettersearch talk future search engine',
#  '#hp open mobile park amp content incubator #apple construct pop',
#  'kawasaki c lewis level reason continue existence evidence existence god #bawling',
#  'kawasaki pagemaker save oh day #jwtatl #enchantment',
#  'kawasaki pagemaker save oh day #jwtatl #enchantment via',
#  'spark #android #teamandroid award read',
#  'unboxing #apple',
#  '#apple great thought w japan apac region deal w earthquake amp tsunami trauma #sxswi',
#  '#apple school #marketing expert cnet blog',
#  '#apple school marketing expert',
#  '#apple school marketing expert',
#  'temporary #apple def tent powerhouse gym',
#  'temporary #apple th congress along happy hipster',
#  '#apple win open temporary downtown support #ipad launch good',
#  '#ipad #austin trend today fun nerdy nerd',
#  'head #austin check map newbie enjoy',
#  'funny #austin trend matter minute point least accord twitter',
#  'christian #ipad #iphone devs want talk u maybe wk together cool',
#  '#ux #ipad #uxdes remember ultimately aware audience target towards unexpected experience good',
#  '#ipad take #austin storm excite part #mobile',
#  'haz #ipad ifrom gr',
#  'stack #ipad wait buy got mine hassle handle perfectly',
#  '#google #mobile future elusive power via #eurorscg #sxswi',
#  '#notatsxsw free download meet nearby pep',
#  '#smallbiz need review play place get #seo',
#  '#smallbiz need review play place get #seo',
#  '#samsung #sony follow #apple #hp lead #austin #atx',
#  '#samsung #sony follow #apple #hp lead #austin #atx via rg',
#  'take major south korean director get make movie entirely',
#  'beautiful pic',
#  'q #sxswi prep amaze pre push locally focus location base own region billboard #pr chat',
#  'account need follow apps download',
#  'head want share gather contact info turn business card broadcaster',
#  'head want share gather contact info turn',
#  'btw sell g model vzw amp amp',
#  'must lovely review forbes holler gram',
#  'temporary sneaky usual',
#  'anyone pop gotta hop place today',
#  'beta test interactive book moonbot studio louisiana cool',
#  'day one see ton #ipad',
#  '#fastball give away two wifi g black cover tweet fo info #sxswi #attsxsw tonight bo lt house',
#  'anyone chance check pop wonder worth trek convention center',
#  'sell everything except gig wifi white manage get',
#  'sell everything except gig wifi white also know white jean configuration',
#  'offer promo ninjafinder user fan suck',
#  'conference search interactive music film',
#  'anyone know sell',
#  'anyone know shipment ipads yet',
#  'marc ecko launch #iphone autodial political change #edreform #edtech #eduvc #fightthepaddle',
#  '#poursite learn life change impact real people actual life bravo',
#  'lonelyplanet guide #iphone free limited time #lp #travel',
#  'free mp downloads time itunes',
#  'anyone head aclu event see owt circle',
#  'prompt memory go map describe childhood walk',
#  'still short line',
#  'essential tool',
#  'leave tradeshow demo theatre ok get see presenter use',
#  'follow tweet realtime four platform tweet deck listening panel realize spoken one today',
#  'anyone want line pick one someone willing pay grab',
#  'anyone want make quick hundred dollar #ipad ad hoc get hundred plus cost',
#  'solve induced toilet crisis crisis',
#  'monday barry diller york time congress lunch w hotel party party six dirty martini monday',
#  'attend guide free download itunes #lp',
#  'seriously test mobile apps constant crash cause lose schedule sync wp',
#  'ready apps make ur blogging easy #sxswi',
#  'conflagration doofusness',
#  'attention er rumor pop temporary launch need',
#  'go #sxswi lousy #ipad',
#  'hey #sxswi folk want learn security come #bsidesaustin',
#  'attend #sxswi work game development look hire base io developer man let talk',
#  '#winning picture #android #google',
#  'gsd amp best party hit tonight',
#  'gsd amp industry party great meet',
#  'spent come already use wait couple city block #ipad',
#  'day marissa mayer connect digital amp physical world mobile',
#  'behind email give line compose reply #protip',
#  'like pm night line around block popup store sell',
#  'free song year alone',
#  'million mobile user map mobile',
#  'currently people line pop',
#  'available gb wifi model plus optional leather smart cover',
#  'love entertain please grateful #edchat #musedchat #sxswi #classical #newtwitter',
#  'less hour announce detail giveaway #sxswi',
#  'see wild people say fast still pic terrible',
#  'queue course',
#  '#ipad take video',
#  'many snap away keynote slide',
#  'user credit card sync itunes one click purchase #winning',
#  'nd cocktail texas snowflake #cnngrill',
#  'post apps use south southwest interactive #sxswi',
#  'post apps use south southwest interactive #sxswi',
#  'sweet map demo go ballroom',
#  'million mile per day drive map navigation',
#  'p #ipad line longer wide people one hour',
#  'u smart pack extra way sunny extra stow case',
#  'wonder sqwill attempt block gowalla cross checkins way facebook block contact connection #lbswars',
#  'day #apple still line grow',
#  'check step bulletproof ux strategy #rhjr ux',
#  'wander th street girl stop ceviche mojitos juice amp ice cream',
#  'band want share track audience stage use frostwire wi fi available',
#  'get busy week ahead book #google apps available amazon amp attend',
#  'believe go aussie sell go buyer report',
#  'spreadsheet party year plan go party',
#  'guy line pop sixth street guy tell',
#  'u need car use zimride etc share rid #shareable',
#  'see lot tablet every single one',
#  'receive lot message tell sexy response post look meet fellow christian devs',
#  'pick mophie battery case prep lug around laptop amp use phone huge win last year',
#  'thats news p launch major social network call circle possibly today',
#  'take piss trade show one hand piss kiiiiiilling right',
#  'rumor monger good read #google #circles preview via #socbiz #fb',
#  'hobo shotgun game',
#  'hobo shotgun video game come user yes please',
#  'build le hour one big launch company history get #apple #ipad',
#  'take survey starbucks line get free starbucks gift card instant research instant gratification #gsdm',
#  'temporary retail release today open pm #sxswi #ipad',
#  'read #groupme sound like incredible available phone yet',
#  'wonder circle gt reveal social network',
#  'search local marissa mayer',
#  'wonder street closure make map show #austin',
#  'another go social circle #google',
#  'question inside fire way',
#  'paraormal activity sanctuary game sketch ar experience interactivity magic lense #eduar',
#  'iie ad si swimsuit issue garage sale',
#  'flipboard add instagram photo social search apps #apple #socialsearch',
#  'spent aftrnoon frozen lake photograph brother scott amp team catch th weeknd',
#  'alarm botch timechange many er freak late flight miss panel behind bloody mary',
#  'shouts lady hold free show take photo sip free beer cc',
#  'dj hoodie allen due respect probably make way back',
#  'meant also wish #dyac stupid',
#  'audioboo american dream bust #ipad #bum #begger #us #socialart #documentally',
#  'skifta base medium shift service turn phone #mashable #sxswi',
#  'rumor open th amp congress sign point yes',
#  'security guy lock',
#  'security guy lock realtime curated',
#  'get cc',
#  'pick pop minute wait',
#  'brilliant enlighten game mechanic presentation',
#  'gsd amp sit tree #gsdm',
#  'pic win #unsix cc cont',
#  'thirsty chevy volt lounge w others',
#  'thirsty chevy volt lounge w others',
#  'come leave playing song choose random skream listening record wall appropriate',
#  'marketing sale genius #apple',
#  'arduino flame skull refrigerator speak salon k pm #smartthings',
#  'reminder chrome tt talk pm today',
#  'v v world panel today pm',
#  'backupify announces cloudsight search first searchable archive solution social medium apps #sxswi',
#  'announce social network circle via tweet interest myopia cause buzz joke interest',
#  'need laptop dictaphone vid camera wow love meet real cerebellum charge people',
#  'u see anything circle',
#  'ridiculous personal planner next day',
#  '#android huge prop amp get',
#  'find kyping geolocation amp release background need patch #batterykiller',
#  'live rsvp event phone amp check sundayswagger eventbrite com #scoremore',
#  'screen miss',
#  'love awesome must see #android bizzy',
#  'pop nut still pack',
#  'say popup',
#  'break announces partnership w porn industry #ipad video chat call facetime',
#  'course build temp texas understand concept corral cattle #pickmeupanipad',
#  'love let something like retail near keep away open pop',
#  'surprise open pop nerd town get #cnet',
#  'surprise open pop nerd town get ipads #cnet',
#  'surprise open pop nerd town get ipads http',
#  'surprise open pop nerd town get ipads',
#  '#technews head set temporary #tech news #apple #ipad #rance wilemon #tech',
#  'great example retail lay future register checkout line',
#  'open temporary downtown launch #gswsxsw',
#  'open temporary downtown launch oh yay traffic',
#  '#technews open pop #tech news #american statesman #apple #apple #tech',
#  '#technews open pop geekfest #tech news #apple #brian lam #ipad #tech',
#  'popup open noon fresh shipment pretty sure go get one finger cross',
#  '#technews save set open pop #tech news #apple #tech',
#  'school marketing expert',
#  'school marketing expert',
#  'school marketing expert via',
#  'school marketing expert via lt lt true love loathe one marketing like',
#  'school marketing expert cnet',
#  'school marketing expert cnet blog #austin #atx #retail',
#  'downtown open til midnight still time',
#  'downtown open til midnight leave stock',
#  'congress #austin',
#  'mall sunday x crowd line fake need fuck dongle genius let',
#  'wks th street open',
#  'special opening th congress amp launch www com retail thedomain #apple #ipad #fb',
#  'makeshift th congress kid amazing #apple',
#  'temporary huge line',
#  'temporary really cool #apple #fanboy',
#  'temporary set shit temptation go control',
#  'temporary line go around block',
#  'temporary open th amp congress tomorrow #ipad',
#  'temporary open pm th congress line already grow #ipad view io via',
#  'temporary block office wait see line tomorrow photo come #ipad',
#  'open noon day close run buy stock year ago',
#  'base camp',
#  'news apps last year',
#  'apps probably need use',
#  'million mobile map user',
#  'line already form pop people see festival',
#  'mobile apps use',
#  'attend report see phone get bannka',
#  'apps like software development release start work update',
#  'tweet stall data sluggish come amp verizon embarrass customer switch #iphone',
#  'tweet come circle platform today outside circle keep #itsnot',
#  'stupid find mac special price #games #mac',
#  'slate see much traffic mobile safari #electricnews',
#  'unload #apple corner th congress temp',
#  'great day jaloux amp look school bus st day school',
#  'arrive issue resolve die use cant login',
#  'screenburn launch client game #travellerarlaunch find',
#  'anyone want see demo piccraft find',
#  'could spend teach theater alone look schedule',
#  'meet u fado give wristband magically lead beer come say hi',
#  'want set temporary check',
#  'overheard relax computer agree #ipad #apple',
#  'overheard interactive arg hate want blackberry back #shocked',
#  'meet author host devs sit pm hilton room ab',
#  'come cool technology one ever heard go conference',
#  'set square foot temporary sell ipads test potential traffic',
#  'overheard launch product people event',
#  'nerd bait set open popup shop core action',
#  'long line else',
#  'last year #sxswi everbody talk year social medium drive revolution year well',
#  'long line pop great marketing',
#  'people work people rather people work #agileagency',
#  'knackered home play updating timeline smash partytweets make go bed',
#  'overheard mdw second halfway battery already even board plane #amateurhour',
#  '#technews school market expert #tech news #apple #jobs co #tech',
#  'first day fun final presentation doodle #googledoodle',
#  'huge line #apple #austin crowd trip get',
#  'ur #google #aclu party u',
#  'queue pop',
#  'post dmi house intimate stranger stage get restaurant crowd sit deal wif',
#  'woman talk sound like chelsea handler lol',
#  'laugh spent week haul macbook everywhere really want shoulder rub',
#  'attendee need qr code reader tweet u image badge first get optiscan free',
#  'hey attendee hop line #apple four day til come',
#  'anyone attend amp aclu party could plz picture thanks',
#  'march tx people line registration',
#  'land spotted place ad airport ultimate pocket guide like #yelp #itouru',
#  'take away lego pit replace recharge station might check price crap samsung',
#  'awesome meet stand queue yesterday day lt lt cute',
#  'bad show late qs process poo poos idea leave early even creative busy #gamestorming',
#  'bahrain govt turn earth result people learn govt turn back',
#  'try balance power power need vs g suck quick might go airplane mode',
#  'race ballroom see marissa mayer #sxswi',
#  'battery #winning',
#  'battery keep tweet thanks #precommerce',
#  'another wave interrupt regularly schedule geek programming w big #google news',
#  'fun watch #ipadmadness open pop',
#  'control #apple set open popup shop core action via cc',
#  'yeah sure gt check #google',
#  'celebrate beauty web msft #ie launch amp play #html game win',
#  'texas amaze meet many influential people work twitter foursquare microsoft even #winning',
#  'woke finish recharge mean get enough sleep last night right',
#  'quiet storm look forward see marissa mayer',
#  'company believe #nfc nexus nokia also carriers verifone even seem #sxswnfc',
#  'best thing heard weekend give money #japan relief need',
#  'good time improve',
#  'cu pacman singularity noobs meetup',
#  'go beyond earth hour year share positive action world download #earthhour',
#  'far big mistake bringing charger',
#  'v bing #bettersearch bing shot success w structure search potentially high margin cpa model v #google',
#  'course bing result good #seo #qagb',
#  'black white #ipad question',
#  'hootsuite blog social medium dashboard hootsuite mobile update blackberry amp',
#  'hootsuite blog social medium dashboard hootsuite mobile update blackberry amp',
#  'hoot blog post hootsuite mobile update blackberry amp',
#  'anyone bring vs computer',
#  'impulsive buy friend gt one selling st gen gb g',
#  'buy #geekdate #apple #ipad',
#  'someone buy present opening pop',
#  'nice find rsq #ipad #app',
#  'south southwest panel illustrate pic sometimes best #news #ogilvy #trending #cyber #iphone',
#  'calendar saturday night giant overlap party',
#  'canadian tuxedo lose hour',
#  'anyone make cooler launch groupon live social type reward',
#  'excite wait open temporary downtown amp launch',
#  'great certain meeting hello holler gram #hollergram',
#  'dont miss charles chen chromeos access booth exhibit hall pm',
#  'reminder charles chen talk chromeos access today pm booth exhibit hall',
#  'tomorrow charles chen speak chromeos access booth exhibit hall pm',
#  'group chat apps tell l two apps yet avail point need phone apps',
#  'remember chime tweet #nasatweetup experience pm pm central time session',
#  'daily chord tuesday march hacker discover music servicestory rollin #music #news',
#  'daily chord tuesday march hacker discover music servicestory roll stone mo',
#  'circle',
#  'circle ht maybe reconsider shape',
#  'circle buzz corner round might find today #google',
#  'circle launch product plenty else',
#  'classic miss blog com twitter pm',
#  'tool collaboration across boundary webex dropbox whiteboarding basecamp join #evolvingworkplace',
#  'try collaborate event friends calendar plancast',
#  'come hear speak min design interface navigation schemas ballrm #uxdes',
#  'come guess pretty desperate give attention',
#  'come sure download go schedules location event',
#  'seriously consider leave macbook pro home fly solo week think make work',
#  'among cool goofy thing spy today case make look like etchnsketch grow game tug war',
#  'wish could party instead homework tomorrow',
#  'could find probably fit',
#  'check coyne pr update via',
#  'crazy look around realize last year one',
#  'crazy big crowd',
#  'u read article say rumor launch major social network call circle',
#  'l amp come uj booth acc hall snap pic amp send em u #fightthepaddle',
#  'shipment daily follow #appleatxdt update pop seem pop',
#  'day tire hold week death happy death',
#  'beautiful day #austin come grab slice two check #google get deal #sxswi',
#  'four day #ipad #weekend #battlela',
#  'dead find secret batphone',
#  'debut selective social network today #google #circles',
#  'try decide session attend marissa meyer later today give',
#  'excellent deck nth time lucky social network launch maybe',
#  'default state user leisurely contemplative #ipad',
#  'mobile definitely hot topic year every session stand room next lesson learn building netflix',
#  'deliberately chose march availability know large chunk customer base',
#  'tv demo league extraordinary hacker cool stuff like web apps tv #google #lxh',
#  'best design big chunky element generous space clarity trump density tap quality trump tap quantity #tapworthy',
#  'attend design interface navigation schema w great stuff far',
#  'attend design interface navigation schemas akqa lynn teo ballroom yes hiring',
#  'check design #uxamandroid',
#  'check design interface navigation schema #uxdes',
#  'check design interface navigation schema #uxdes',
#  'head design interface navigation schema #uxdes',
#  'take design interface navigation schema #uxdes',
#  'adobe develop engine essentially convert swf file jquery html exist flash file portable',
#  'developer awesome name event join league extraordinary #h ckers',
#  'behaviour diff lot phone call use laptop notsomuch mobile internet',
#  'lovin digital band sings amp play guitar fan record vids #cnn digital #cnngrill #sxswi',
#  'barry diller think content nut',
#  'really need another big social network right thanks #google',
#  'q u think check offer test #smccolumbus',
#  'japan docomo introduce mobile apps six year come #jpmobilesummit',
#  'time #apple open pull #ipad trigger',
#  'forget come #privacybootcamp startup',
#  'forget come #privacybootcamp startup acc abc cst',
#  'bad button know time abnormal amount update',
#  'web devs wait line signup relic use promo eligible win one',
#  'download free track music sampler available today',
#  'download free track music sampler available today',
#  'download free track music sampler available today #fb',
#  'downloadfree track music sampler available green lady killer',
#  'guess draw big crowd chimp could work #iphone sorry',
#  'jeez guy dunno pop gold gym u realize un job aesthetic #apple',
#  'anyone else use #hashable network week try version',
#  'enjoy ride anywhere download #groundlink booth',
#  'enjoy ride anywhere dwnld #groundlink booth',
#  'even begin #apple #winning via',
#  'even begin #apple win #tc #apple',
#  'even begin #apple win',
#  'even begin #apple win open temporary downtown support #ipad launch #genius',
#  'even begin #apple win past week major dilemma',
#  'even begin win techcrunch #ipad',
#  'even begin win',
#  'even begin win',
#  'even begin win',
#  'even begin win',
#  'even begin win via',
#  'even begin win',
#  'even begin win via',
#  'even begin win gt gonna get sum via',
#  'even begin win techcrunch',
#  'even begin win lt lt win big',
#  'even begin win #apple #ipad #pm',
#  'even begin win #apple #ipad #tc',
#  'even begin win #apple',
#  'even begin win #tc #apple #ipad',
#  'even begin win via #apple',
#  'even begin win via #apple',
#  'badgeless event free drink head free sponsor happy hour semantic web fogo de ch',
#  'best swag ever thanks charge thanks',
#  'thanks everyone make great day shop today come see u tomorrow',
#  'thanks everyone come today good luck win stop tomorrow chance win',
#  'time everything brand winner #pnid',
#  'hey exhibitor capture booth experience retrollect disc popular disc win',
#  'sq see facebook competition via #checkins',
#  'fantastic schedule bummer still crackberry',
#  'photo far best accessory follow closely margarita',
#  'one fav photo far amp #google',
#  'watch fb big brother launch major social network call circle possibly today',
#  'think fell bit love #google today thanks throw nerd party speakeasy',
#  'way figure good replacement make year',
#  'dslr film discussion moderate guy kawasaki fame pack house',
#  'get film red carpet coverage cw star mandy dugan group get',
#  'need find good stream follow inane tweet surely southby',
#  'find stupid stupid game #ipad currently special sale',
#  'find hot spot w hot spot #wp',
#  'try find pop #widfy',
#  'first person queue may',
#  '#technews flipboard add instagram photo social search apps #tech news #apple #social search #tech',
#  'il ceo di flipboard annuncia la versione next platform flipboard team start work',
#  'focus bridge digital physical divide eg map streetview hotpot amp autonomous driving',
#  'hey folk please keep u posted #circles hope blast',
#  'hey folk free lunch la condesa pepsi max lot map',
#  '#apple follow customer forbes alcoholic call enable rest u call genius',
#  'please follow next big #college social network chance win #ipad follower #socialmedia',
#  'gear list music vzw blackberry sprint jambox hp elitebook lack good portable headphone suggestion',
#  'prepare talk #google doodle fun friday pm',
#  'good news bound fanboys #ipad',
#  'save photo @jerranalley @tbalinas',
#  'wish list tech #ntn apps help level play field kid may software home',
#  'design catch matt carlson amp matthew davis mon hilton',
#  'hitlantis cool song explorer hitlantis com #musicviz',
#  'search temporary',
#  'thank public note step bulletproof ux strategy #rhjr ux via',
#  'queue form pop guy front since apparently',
#  'frankenstein amalgamation fragment digital identity become anti schizophrenic ai sm sci fi',
#  'want free #music free sampler album #itunes download open itunes',
#  'free song sampler available download itunes artist play check #music',
#  'win free webdoc com',
#  'grab free music showcasing artist mp torrent wild',
#  'hey friends anyone charger borrow tonight lmk',
#  'friend willing pick pay premium dm #atl',
#  'good talk akqas interface w callback design principle wish go beyond medium market example #fb',
#  'person front take picture',
#  'tessie frontwoman intimate stranger ink painful place get ink respect location',
#  'future local contextual discovery marissa mayer argue exceptionally valuable type search',
#  'future touch user interface design wonder presentation microsoft employee mention',
#  'geek game compete gain vip status amp win big prize know #mashable #geek game #cyber #iphone',
#  'gear make splash launch groupon live social type reward boom',
#  'zazzle gear hit look tweet come create case #zazzlesxsw',
#  'marketing genius open pop outside',
#  'get look rumor #apple pop',
#  'try get #google retro party maggie mae line huge hope worth wait',
#  'get ready word circle trend #sxswi #google #circles #social',
#  'get soundcloud start record use sq geotagging map',
#  'get food forget snap photo win macbook air tv',
#  'get full underway tell intermittent brick #crowded',
#  'give social networking another try circle via',
#  '#at amp give away amaze prize kindle tablet amaze happen sheraton',
#  'zaarly give away person beta signup referral #craigslistkiller',
#  'give free lab laptops open source coder r attend meet get cupcake',
#  'go available blackberry window addition',
#  'need go mo old sitter know score martin like #babyheadphones',
#  'go next year open temporary',
#  'want go pop afraid leave',
#  'hey goer droppin survival tip week help get rock best hangover cure tamale house',
#  'bomb go convention center go lose devastate share customer base',
#  'omg go macbook pro ipod galaxy tab #techgeek',
#  'go want talk html cs catch webmaster team',
#  'go see tonight',
#  'golden ticket f sq party day real party #redbullbpm felix da housecat playing',
#  'good morning u enjoy ride anywhere dwnld #groundlink booth',
#  'queue er bing talk spam ridiculous busiest see',
#  'haha party like party',
#  'gsd amp party blow mind much amaze food drink music amp photo booth fun',
#  'authenticator mobile device step ahead',
#  'circle first real alternative facebook',
#  'circle launch may good time give twitter',
#  'place value domain extension equal #qagb',
#  'attend keynote see map mobile feature',
#  'name build get thing try marissa mayer frm',
#  'let block site stand block look like need',
#  'length penalty base severity breach webmaster guideline e white text white bgr might get day pen #qagb',
#  'set launch social network #circles today',
#  'need lonelyboy talk time #enchantment',
#  'launch major social network call circle possibly today update happen',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today something keep watch',
#  'launch major social network call circle possibly today never beat myspace',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today big gaga',
#  'launch major social network call circle possibly today #fb',
#  'launch major social network call circle possibly today #hnwsxsw',
#  'launch major social network call circle possibly today goog',
#  'launch major social network call circle possibly today dejavu',
#  'launch major social network call circle possibly today sta nije im dosta gbuzz',
#  'launch major social network call circle possibly today te dije wey',
#  'launch major social network call circle possibly today super interest',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today #nfusion #hmm',
#  'launch social network call circle today applause privacy model attempt',
#  '#technews launch social network #tech news #aclu #tech',
#  'break launch major social network call circle today via #socialmedia',
#  'diller tv first product good consumer product basically #diller',
#  'connect digital amp physical world mobile',
#  'connect digital amp physical world mobile',
#  'ea game zynga facebook microsoft intuit go gaga go game',
#  'future contextual discovery location context help u go deeply ever search without search',
#  'cutts say reputation topicality key matter site ranking #qagb say trust amp lda',
#  'marissa mayer talk worth go',
#  'ironic google direction party end walked block wrong direction time bed think',
#  'check googletv apps connect tv experience #connectedtv',
#  'check googletv apps connect tv experience #connectedtv fascinating',
#  'cnnmoney get crave mind create foodspotting #iphone #apps',
#  'microsoft get drunk change default search yahoo',
#  'grab late #saytextson',
#  'msc page guy get tattoo could win free #tattoo #ipad #allshare',
#  'bring guy start #touchingstories design digital magazine',
#  'less half hour tell win #sxswi',
#  'hand awesome dude give cutsies hour line #austin #apple #winning',
#  'hand thisisdare',
#  'gonna hang hack nook around neck week become flava flav top hipster #gsdm',
#  'something call place hotpot work recommendation engine',
#  'post nothing',
#  '#smtravel hear plan launch socnet may circle learn lot year lots change via',
#  'bb discriminatory p officially come fc grill amp make ur case',
#  'may invite cool #sxswi party two charger pocket happy see',
#  'would thunk agency push direction never would go otherwise say',
#  'yet see someone pc dell otherwise macbook pro ipads b soon',
#  'meeting line popup love place',
#  '#apple hawk festival popup',
#  'want hear tell love story #connectedbrands #sxswic',
#  'pump hear dude talk logos year make one #gsdm',
#  'thanks heathcare digital publishing news medical apps showcased #sxswh',
#  'hello enjoy ride anywhere download #groundlink booth',
#  'oh lordy go time #apple open pull #ipad trigger',
#  'hey know little #iphone #android love music amp wanna make hour please let know',
#  'love honesty marissa mayer keynote many product need step customer service location',
#  'host developer day',
#  'minus hour social medium maven start perform degrade sex act charge',
#  'hey bout donate spending #ipad japan really need thing',
#  'wonder much revenue gross account amid strategic release',
#  '#technews win hint answer every year #tech news #bill murray #how #iphone #tech',
#  'hp popups gee wonder get traffic',
#  'scavenger hunt game business release',
#  'wonder fit luggage pack hmmm',
#  'holy moly believe line',
#  'time ever torrent also legal also also excite',
#  'could forget cell phone today fail glad #lifelinetotheworld',
#  'g hr tweet #rise dead need upgrade plugin station',
#  'feel bad place try amp get everyone try get one #techiesunite',
#  'love macbook year one run juice jump next',
#  'holy cow get hooked paolo alex backup charger facebook com powermat #powermatteam #thanks',
#  'holy cow get hooked paolo alex backup charger facebook com powermat #powermattteam #thanks',
#  'catch mean #apple #ipad',
#  'knew ply beer stogy last night weasel way team party tonight #success',
#  'honestly think everyone own laptop #truestory',
#  'ok nerd totally bateman want sign',
#  'last year travel heavy year light get right next year leave home',
#  'thought would use lot even touch hmmzies',
#  'convention center today w fam show game',
#  'cool one friday pm doodle session',
#  'beyond frustrate w samsung moment runaround amp leave att amp enjoy',
#  'ev ry day hustlin work event tonight absolutely love work',
#  'brilliant idea search engine rank session small room people lock',
#  'idea startupbus thing addictive also add',
#  'practical idea development bit ly androidhig',
#  'wonder anyone sell verizon bueller',
#  'show st gen still let door funny tim',
#  'hot spot data speed could keep also thanks release ios time',
#  'wonder ppl friday queue convention centre xd still figure wot',
#  'wonder crowd make line store elsewhere u short today',
#  'another interview disaster like last year evan wood one see alot star',
#  'able afford attend buy today consider save japan earthquake relief',
#  'imago future ask want know search #smscifi',
#  'launch imminent apparently circle probably even',
#  'week #ipad clip join review free go #app #ipad #sxswgo',
#  'room full people w good wi fi run #frostwire share pic apps vids w others',
#  'room full people w good wi fi run #frostwire share pic apps vids w others',
#  'hot spot gowalla right convention cnt ignite party n #sxswi',
#  'weekend support smarty ear launch apps speech therapy #sxswh #sxsh',
#  'today please join talk',
#  'guy front panel etch sketch case device wonder #iusxsw',
#  'need sweet mac goodness set temporary downtown',
#  'currently route truther movement music festival spiderhouse',
#  'release #socialmedia tool',
#  'nfc include maybe',
#  'influence ditto one button login choice facebook #understandinghumans',
#  'wabi sabi inspiration lab look spanish speak trend scout base texas',
#  'zite intelligent magazine lt deliciousness #trending #youneedthis',
#  'interested location base tech indoor venue business convention center etc tech need improve first',
#  'hmm interest wonder put tip api #suxsw',
#  '#thekills interview may one painfully vacuous interview history',
#  'get first panel today line look like',
#  'tim soo invisible instrument jaw drop wii controller #lovemusicapi',
#  'rockin downtown #apple',
#  '#technews get temporary #tech news #apple #apple #ipad #tech',
#  'awesome jailbreak grateful dead #fab',
#  'heard launch pretty intense',
#  'post launch huge line pop shop #sxswi',
#  'sell go buyer report #socialmedia #tech #ipad #media',
#  'remain stock come get one',
#  'accessory bag thanks',
#  'pure gold',
#  'check design headaches tablet call morning #tapworthy',
#  'first design headache tablet call morning #tapworthy',
#  'first even exist last year already feel like pull antique everytime use #ipad',
#  'design interface navigation schema #uxdes',
#  'design interface #uxdes',
#  'turn physical message platform holler gram cheeky build',
#  'spin play launch party hang cedar street courtyard',
#  'shoot display search result go question later #osmpw',
#  'pic win performance #accordion #toodamnlucky',
#  'fear #att g slowpoke network amp #sxswmusic',
#  'mock like money come',
#  'one bad use long time',
#  'cool launch flypost community bulletin board w location learn',
#  'pedicab charger would epic win',
#  'check developer meet',
#  'transient device use short burst pm couch device',
#  'fret owner open temporary via',
#  'dislike twitter auto shorten link',
#  'clearly positively happily',
#  'clipboard carny #ipad #lowtech',
#  'compete circle socialflow board resonant topic',
#  'flipboard develop version say',
#  'microsoft go launch ie amid glow logo #classicaudiencemisread',
#  'overheat many british sound people texas',
#  'part presentation good thing crash instead work best',
#  '#hashable rock cloud business card #iphone #android',
#  'super friendly w closed acquisition amp partnership answer point',
#  'gamesalad topic dutch podcast #gssxsw #sxswnl',
#  'soo',
#  'sister throw party tonigh come band food art ice cream nifty interactive',
#  'walk around star like everyone else ummmm ditto',
#  'wilt stress',
#  'believe almost always use map map use mobile say',
#  'course get #geeksrule',
#  'rumor put pop congress th strange activity sw corner could shhh',
#  'gotta get hey taariq howdy texas fav lt get #usguys',
#  'rumor open temporary downtown launch #fb',
#  'rumor open temporary downtown launch',
#  'rumor open temporary downtown launch bit ly g mzb',
#  'big small pc good big event like meeti',
#  'big small pc good big event like meeting day',
#  'get #atx',
#  'bit jealous see attendee #ipad seem obsolete',
#  'join u drink tonight pm fado irish pub th love meet',
#  'posterous join pile posterous event techcrunch',
#  'posterous join pile posterous event #iphone #richpearson',
#  'building sprout map mobile',
#  'think break #sorry',
#  '#technews time foursquare ups game #tech news #friends offer #iphone #the game #tech',
#  'learn thing screen year old explanation instantly know use',
#  'location pixieengine say future location location location #cnn',
#  'pick back cha think worth upgrade',
#  'keep tab great #craftbeer drink next pint',
#  'keep awake thank god buy',
#  'keynote marissa mayer acc ballroom w others',
#  'know week tough already dwindle battery help jeebus keep correct curse word',
#  'jon kolko coffee venture accelerator look critically influence edu',
#  'launch social network circle possibly today',
#  'launch social network today',
#  'launch social network circle excite',
#  'launch circle social network',
#  'launch major social network call circle via cc @mentionc',
#  'launch major social network call #circles gt update preview plan',
#  'launch major social network call circle via',
#  'launch major social network call circle',
#  'launch major social network call circle update launch soon care',
#  'launch major social network call circle',
#  'launch major social network call circle',
#  'launch major social network call circle',
#  'launch major social network call circle brazil orkut user wait',
#  'launch major social network call circle via',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today #sxswi via',
#  'launch major social network call circle possibly today update today via',
#  'launch major social network call circle possibly today update happen',
#  'launch major social network call circle possibly today update',
#  'launch major social network call circle possibly today update',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today #circles',
#  'launch major social network call circle possibly today #google #circles',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today surely threat fb',
#  'launch major social network call circle possibly today via #pcbuzz',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today #pakistan #cwc',
#  'launch major social network call circle possibly today lb via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today gt gt good',
#  'launch major social network call circle possibly today course another social network',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today #sxswi via',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today #nfusion',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today via #screenfuture',
#  'launch major social network call circle possibly today via lt #curious',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via',
#  'launch major social network call circle possibly today via #screenfuture',
#  'launch major social network call circle possibly today via #sxswi',
#  'launch major social network call circle possibly today rww f bcet',
#  'launch major social network call circle possibly today rww f bcet #yam',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle possibly today',
#  'launch major social network call circle #google #circles',
#  'launch major social network call circle #google #circles',
#  'launch major social network call circle v',
#  'launch social network #google',
#  'launch social network cnet news',
#  'launch social network #aclu',
#  'launch social network call circle possibly today #in',
#  'launch social network circle link u closely peeps u connect w possibly today',
#  'launch social portal today',
#  'launch product wait launch product exist wait product exist',
#  'launch social network circle deny launch though #google #circles',
#  'launch social network call circle',
#  'launch social network circle point today',
#  'launch social network today update status share video amp photo circle friend',
#  'hootsuite launch analytics integrates facebook analytics look good #hootsuite #hootstats',
#  'launch social network call circle today',
#  'launch social network definitely rumor still #googlecircles',
#  'launch product plenty else join u #h ckers amp dance today',
#  'wikitude layar flar tool argon goggles augment reality browser tool amp apps check #eduar',
#  'lazy',
#  'hope leave open pop',
#  'check leave brain search right brain search x #bettersearch',
#  'check lightbox com team choice award finalist announce team rock',
#  'god like imac macbook blackberry star enough time read book remember',
#  'smell like cheese stick dj work etsy party #realtalk',
#  'ha seem like gt news sxswi temporary #wth',
#  'line #ipad',
#  'line day',
#  'anyone line temporary idea till late open tonight',
#  'people line pass time surf',
#  'saw giant line think movie premiere hear scream premiere',
#  'line temp yet',
#  'list music performer use jquery screen scrape',
#  'people listen #google',
#  'since listen marissa mayer engage twitter wonder heck happen buzz',
#  'location location location via #google',
#  '#tech one lone dude awaits #ipad #apple likely expect big crowd forming #technology',
#  'bet long line gonna',
#  'get look impact dashboard first time',
#  'look social signal search result #qagb',
#  'look hig like guideline design adam beckley #uxamandroid',
#  'look forward bing q website rank week',
#  'radio look band radio show listen #nowplaying #newmusic pls',
#  'anyone lose cab downtown last night please hit',
#  'anyone lose back cab downtown around p tonight please hit',
#  'lot drink amp draw sketchup party',
#  'lot effort help japan many global issue wtf w people',
#  'gotta love unabashed #fanboy gt gt even begin win',
#  'geeky love open temporary downtown launch',
#  'love come w cool technology one ever heard go conference',
#  'love come cool technology one ever heard go conference',
#  'n love town code valid p #infektd #necro',
#  'sketchily lurk big boi concert business hard read massive announcement deadline #lovemyjob',
#  'try make detailed colour cod calendar prove really tough also get organize',
#  '#technews man panhandle world come #tech news #ipad #tech',
#  'many people ipads whole room raise hand half room raise hand #stillonamacbook #shame #nfusion',
#  'hire marketer designer creatives social medium pro come see #aquent booth trade show might win',
#  'love marketing genius inside temporary',
#  'great vid marty #ipad live unbox front video',
#  'think may go laptop today #sxswi veteran reason',
#  'make #soundcloud ambassador upload music show amp reward soundcloud fresh',
#  'come find booth #ipad case leave win #cbatsxsw',
#  'amazes many people tuck flap case',
#  'omfg mean please webber dionne warwick',
#  'alert medium saw one tablet like find needle haystack also saw cr',
#  'n first meeting code valid p #infektd #necro',
#  'great meeting haha #hollergram',
#  'great mental image people session take photo w air #doingitwrong',
#  'purchase mexican mavis boy amp bear sell first listen thanks #itunes',
#  'purchase mexican mavis boy amp bear sell first listen thanks #itunes #free #itunes',
#  'think might go weekend without see case twice',
#  'sure mine via know #agnerd #dairy rely evernote #agchat',
#  'bum miss year quarantine kiddie cold garageband comfort #fb',
#  'miss know spotted nfc enabled place marker bird wonder billboard near',
#  'red mist giant dope interview adi mind adi minute ago compare cat pic location',
#  'hootsuite mobile update blackberry amp',
#  'hootsuite mobile update blackberry amp via',
#  'hootsuite mobile update blackberry amp #android #blackberry #keitai',
#  'hootsuite mobile update blackberry amp #hootsuite',
#  'hootsuite mobile update blackberry amp via',
#  'hootsuite mobile update blackberry amp share paul #shared',
#  'hootsuite mobile update blackberry amp whether get friendly',
#  'mashup mobile contextual information future #google marissa mayer #thefutureismobile',
#  'pat know talk please julia sweeney learn',
#  'well good morning #sxswi day ready another day great panel bc alumni amp industry party tonight #gsdm #google',
#  'love morphie juicepack today recharge worth',
#  'brilliant move even begin win',
#  'hey mover shaker publish poke box ebook next week get involve',
#  'much fun hand chance win audi car',
#  'could murphy usa good serve inside map phone announce great feature v',
#  '#ipad intimate together #tapworthy #designflaws #sxswi',
#  'compile list one doc taking lot long think many party many good musician',
#  'day charger kick bucket heck within walk distance',
#  'good deed return lose',
#  'thanks good friend great gift exogear backup battery case priceless',
#  'sent behind email give line compose reply #protip',
#  'feel unequipped compare everyone else dang',
#  'head sole event aclu dotrights party',
#  'whats name song #imthetype #imthetype',
#  'need page flip effect like fake needle cd player #tapworthy #ipad',
#  'hm need another launch major social network call circle possibly today',
#  'u need group challenge come solve parent issue #worklifeprogress',
#  'need help badass developer right debug emergency know anyone',
#  '#ubersocial #iphone include uberguide sponsor #mashable',
#  '#ubersocial #iphone include uberguide sponsor #mashable fin ly',
#  '#ubersocial #iphone include uberguide sponsor #mashable vamos probar',
#  'couple blog random tip awesome dev politics behind html',
#  'news industry spending r amp wait innovate publisher b c print subsidize effort #newsapps',
#  'hootsuite news hootsuite mobile update blackberry amp',
#  'dude next hold use like trophy #lookingforwardtothemusicfest',
#  'nice huh chance meet face face today sit wanna talk #beer amp #social',
#  'hard feeling towards say would make great partner #checkins #pnid',
#  'hack find people jump corporate firewall e g use docs etc #hackingwork',
#  'hope flop akabuzz launch major social network call circle possibly today',
#  'c retreat code valid p #infektd #cvdc',
#  'rumor popup downtown amp launch smart move many #dfcbto',
#  'anyone hop groupon bandwagon launch groupon live social type reward',
#  'launching product',
#  'launch anything partying #circles',
#  'droid surprise spot table three people phone macbook #gadgetoverload',
#  'buy buy even begin win',
#  'farooqui mobile io catch fast grow allow purchase #gamesfortv',
#  'fear extend wed gt last day popup sunday #appleatxdt',
#  'calvin geek charlie sheen goddess #google',
#  'get feedback group amp push fix grill cheese stand yesterday',
#  'manufacturing serendipity access information make u curious less',
#  'nothing teem sea addict busy twitter ever engage one anoth cont',
#  'fan trend audience share opinion via hold listen #annoying',
#  'map usage mobile marissa mayer',
#  'power people spend hundred dollar attend spend day wait line',
#  'continuum attitude crowdsourcing gap hear tell',
#  'vp consumer product marissa mayer say location everything',
#  'search local information marissa mayer million place claim owner log #google',
#  'third era logo interactive play space get ready #googledoodle #gsdm',
#  'batch deliver #ipad #photo',
#  'highlight day undoubtedly meet second softball fancrazed preso',
#  'cool team startup come via siliconvalley bus hack apps ex au stage w speakermeetup dogpatch lab',
#  'wow lot audience see vector pan map mobile gasp appreciation',
#  'tip day turn screen brightness way #conservebatterylife #peace',
#  'first leg mobile social #fb',
#  'call zombie code valid p #infektd #zomb',
#  'call zombie code valid p #infektd #zomb',
#  'tomlinson tx observer say subscription data hold big impediment success #newsapps',
#  'tip turn push amp set fetch manual mode email mail contact amp cal gt fetch data save battery #iphone',
#  'official go #android #iphone #ipad lt thanks instal',
#  'zazzle officially come grille mention u #zazzlsxsw get make case',
#  '#technews omg jk kiss slap xoom #tech news #ipad #jk #omg #tech',
#  'cr much potential',
#  'idle time friday expensive thing w others pic',
#  'also foodspotting hit find food crave #cnnmoneysxsw',
#  'usa today make good use digital shortcut still look like newspaper #tapworthy',
#  'one hand caramel macchiato ouch hiss hot apparently two pump lava begin #tmsxsw',
#  'thats one want get hit canada sell everything except gig wifi white',
#  '#technews one lone dude await #tech news #apple #ipad #tablets #tech',
#  'one million rating per month hotpot pr',
#  'haz one show charge anywhere bar charge whole table want buy one',
#  'explanation continue success existence god #enchantment',
#  '#apple open pop across street two week umm genius obvious cough #ipad cough',
#  '#apple open pop time #ipad sale',
#  '#apple open pop shop report',
#  '#apple open pop shop report via',
#  '#apple open pop shop report #property',
#  '#apple open pop shop report set open temporary',
#  '#apple open pop shop report set open temporary #realestate #tech',
#  '#apple open pop shop via',
#  '#apple open pop shop',
#  '#apple open pop shop lt cool concept spend wait #ipad',
#  '#apple open temporary',
#  'open time tues amp wed news site manager want chat news let know',
#  'wear openbeta vip badge might win quibids case #sxswbuffalo',
#  'open makeshift available pm today #tempted',
#  'launch soon participate launchrock comp get invite',
#  'hey dexteria available like u facebook',
#  'plenty people line scarf w others',
#  'nice line outside #apple guess people want',
#  'confusion circle claim circle release even development',
#  'pack point show fragmentation',
#  'attend panel well live cloud compute present jon wiley',
#  'one panel moderator europe say spent roaming charge',
#  'brown paper windows line grows popup gold gym sixth amp congress',
#  'two party awesome journalism npr one go pb',
#  'party best ever get butt',
#  'hey peep #voicefeed launch u check let u know think',
#  'watch people interact information different big small #touchingstories #ipad #tablet',
#  'hey people survival tip great vegitarian vegan right think action mr natural #sxswsurvival',
#  'pepsi max market street team show popup line hand drink amp tshirts',
#  'post per rumor may preview big social strategy theme costume party yep',
#  'instagram photo iamtimbaker party',
#  'try pick theme year think may open data government #bolinsxsw',
#  'plan launch major social network call circle preview far super positive',
#  'mashable platform concertgoers launch time',
#  'game play swsx spot non electronics',
#  'need play game #android',
#  'grow men play legos party speakeasy',
#  'leave pocket guide hotel know go cope say usability',
#  'check poke liked amp tweet love story #sxswic',
#  'check poke liked amp tweet love story #sxswic',
#  'temporary pop shop #apple nice flipboard upgrade',
#  'pop joke',
#  'find pop',
#  'pop attractive impressive many permanent retail store',
#  ...]

# %%
sentiments['tokenized'], sentiments['tokens'] = \
    preprocess(sentiments['tweet_text'],sw=sw,ret_tokens=True)

# %%
X = sentiments[['tokenized','tokens']]
y = sentiments['sentiment']

X_train, X_test, y_train, y_test = \
    train_test_split(X,y,
        test_size=0.2,
        stratify=y,random_state=13)

train = X_train.merge(
    y_train,left_index=True,right_index=True
    )

test = X_test.merge(
    y_test,left_index=True,right_index=True
    )

# %%
# train = X_train.merge(
#     y_train,left_index=True,right_index=True
#     )
freq_words = word_plot(train,'sentiment','tokens',
    n_words=15)

# %%
print(freq_words[1])
sw.extend(freq_words[1])
train['tokenized'], train['tokens'] = preprocess(train['tokenized'],sw,ret_tokens=True)
freq_words = word_plot(train,'sentiment','tokens',
    n_words=15)
# Out:
# Index(['#ipad', 'get', 'launch', 'line'], dtype='object')

# %%
print(freq_words[1])
sw.extend(freq_words[1])
train['tokenized'], train['tokens'] = preprocess(train['tokenized'],sw,ret_tokens=True)
freq_words = word_plot(train,'sentiment','tokens',
    n_words=15)

# %%
sw.extend(freq_words[1])
train['tokenized'], train['tokens'] = preprocess(train['tokenized'],sw,ret_tokens=True)
freq_words = word_plot(train,'sentiment','tokens',
    n_words=15)

# %%
freq_words[1]
# Out:
# Index([], dtype='object')

# %%
word_plot(train,'sentiment','tokens');

# %%
# tfidf = TfidfVectorizer(ngram_range=[1,3],max_df=0.4,min_df=20)
# X = tfidf.fit_transform(sentiment_tokens)

# %%
# vect = pd.DataFrame(X.toarray(),columns=tfidf.get_feature_names())
# vect.head()
